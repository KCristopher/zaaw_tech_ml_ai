# %%
import joblib

model = joblib.load('gradient_boost_created_2026-02-01 10-20-47.joblib')
model
# Out:
# GradientBoostingClassifier(learning_rate=0.05)

# %%
import pandas as pd

data = pd.read_csv('sample_rows_to_predict.csv', index_col = 'ID')
data
# Out:
#      bill_depth  bill_length  wing_length  location    mass  sex  \
# ID
# 185   14.982114    47.504878   202.811884       1.0  4200.0  0.0
# 503   15.800000    45.200000   215.000000       0.0  5300.0  1.0
#
#      bill_length_nan
# ID
# 185                0
# 503                0

# %%
model.predict( data )
# Out:
# array([2, 2])
